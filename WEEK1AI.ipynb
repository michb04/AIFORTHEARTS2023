# %% [markdown]
# # Week 1: Getting started with Anaconda, Jupyter Notebook and Python
#
# ## Motivation
# I chose to join this course because I am passionate about artificial intelligence and its potential to transform various industries. My would like to become proficient in AI and apply my skills to solve real-world problems that could make a positive impact.
#
# ## Prior Experience
# I have some prior experience with programming but not specifically in python. However, I am interested in learning more
#
# ## Learning Expectations
# - Gain a solid understanding of the basics of Python programming.
# - Learn how to use Jupyter Notebook
# - Understand key concepts in AI and machine learning.
# - Build a foundation for further studies and projects in AI.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Changing the value of message
message = "Hello, Python World!"
print(message)

# Printing message + message
print(message + message)

# Printing message * 3
print(message * 3)

# Printing message[0]
print(message[0])  # This will print the first character of the string

# Changing the variable name
greeting = "Hello, Python World!"
print(greeting)
# Out:
# Hello, Python World!
# Hello, Python World!Hello, Python World!
# Hello, Python World!Hello, Python World!Hello, Python World!
# H
# Hello, Python World!

# %%
from IPython.display import *

# %%
from IPython.display import YouTubeVideo


YouTubeVideo("DHfRfU3XUEo")
